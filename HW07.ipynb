# %%
import surprise
import pandas as pd
import numpy as np

from tqdm.notebook import trange
from surprise import Dataset, Reader, SVD, SVDpp, NMF, accuracy
from surprise.model_selection import  cross_validate, train_test_split, GridSearchCV
from surprise.dataset import DatasetAutoFolds

# %%
data = Dataset.load_builtin('ml-100k')

# %%
reader = Reader(rating_scale=(1, 5))
raw_ratings = data.raw_ratings

# %%
trainset, testset = train_test_split(data, test_size=0.2)

# %% [markdown]
# # Огляд даних

# %% [markdown]
# ##### DF

# %%
df = pd.DataFrame(raw_ratings, columns=['userId', 'itemId', 'rating', 'created']).drop('created', axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   userId  100000 non-null  object
#  1   itemId  100000 non-null  object
#  2   rating  100000 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 2.3+ MB

# %%
df.describe()
# Out:
#               rating
# count  100000.000000
# mean        3.529860
# std         1.125674
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000

# %%
df.head()
# Out:
#   userId itemId  rating
# 0    196    242     3.0
# 1    186    302     3.0
# 2     22    377     1.0
# 3    244     51     2.0
# 4    166    346     1.0

# %%
len(df)
# Out:
# 100000

# %% [markdown]
# ##### Train DataSet

# %%
trainset

# %%
train_data = trainset.build_testset()
train_df = pd.DataFrame(train_data, columns=['userId', 'itemId', 'rating'])

# %%
train_df
# Out:
#       userId itemId  rating
# 0         28     56     5.0
# 1         28    217     3.0
# 2         28    588     3.0
# 3         28    859     3.0
# 4         28    201     3.0
# ...      ...    ...     ...
# 79995    794     14     5.0
# 79996    794    248     4.0
# 79997    794    109     4.0
# 79998    794    257     4.0
# 79999    794    238     5.0
#
# [80000 rows x 3 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   userId  80000 non-null  object
#  1   itemId  80000 non-null  object
#  2   rating  80000 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 1.8+ MB

# %%
train_df.describe()
# Out:
#              rating
# count  80000.000000
# mean       3.529375
# std        1.125468
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        4.000000
# max        5.000000

# %%
len(train_df['userId'].unique())
# Out:
# 943

# %%
len(train_df['itemId'].unique())
# Out:
# 1654

# %% [markdown]
# ##### Test DataSet

# %%
testset
# Out:
# [('532', '215', 5.0),
#  ('222', '549', 4.0),
#  ('404', '323', 3.0),
#  ('869', '122', 3.0),
#  ('631', '288', 3.0),
#  ('537', '150', 3.0),
#  ('244', '953', 4.0),
#  ('246', '385', 1.0),
#  ('25', '176', 4.0),
#  ('85', '319', 4.0),
#  ('715', '376', 2.0),
#  ('345', '284', 4.0),
#  ('715', '98', 5.0),
#  ('308', '965', 4.0),
#  ('393', '659', 4.0),
#  ('216', '216', 4.0),
#  ('32', '307', 2.0),
#  ('474', '410', 2.0),
#  ('40', '333', 4.0),
#  ('386', '24', 4.0),
#  ('699', '886', 3.0),
#  ('551', '3', 5.0),
#  ('320', '1081', 4.0),
#  ('648', '797', 3.0),
#  ('197', '227', 3.0),
#  ('70', '511', 5.0),
#  ('711', '312', 5.0),
#  ('705', '597', 4.0),
#  ('41', '1', 4.0),
#  ('864', '98', 5.0),
#  ('496', '174', 4.0),
#  ('201', '42', 4.0),
#  ('894', '271', 2.0),
#  ('6', '269', 4.0),
#  ('308', '87', 4.0),
#  ('889', '654', 3.0),
#  ('121', '937', 4.0),
#  ('299', '962', 4.0),
#  ('43', '289', 4.0),
#  ('830', '241', 4.0),
#  ('922', '80', 3.0),
#  ('20', '678', 4.0),
#  ('666', '180', 4.0),
#  ('450', '223', 3.0),
#  ('669', '483', 3.0),
#  ('757', '742', 4.0),
#  ('417', '167', 3.0),
#  ('374', '948', 2.0),
#  ('5', '186', 5.0),
#  ('7', '356', 4.0),
#  ('923', '3', 4.0),
#  ('497', '381', 3.0),
#  ('716', '519', 3.0),
#  ('330', '969', 5.0),
#  ('825', '283', 2.0),
#  ('637', '931', 1.0),
#  ('16', '496', 5.0),
#  ('334', '193', 4.0),
#  ('659', '762', 3.0),
#  ('707', '863', 4.0),
#  ('409', '173', 3.0),
#  ('450', '1221', 5.0),
#  ('887', '559', 4.0),
#  ('399', '77', 2.0),
#  ('288', '199', 4.0),
#  ('871', '161', 5.0),
#  ('659', '178', 5.0),
#  ('859', '151', 2.0),
#  ('188', '554', 2.0),
#  ('602', '261', 3.0),
#  ('621', '410', 4.0),
#  ('508', '168', 4.0),
#  ('585', '165', 4.0),
#  ('472', '101', 5.0),
#  ('396', '222', 5.0),
#  ('907', '485', 5.0),
#  ('244', '310', 3.0),
#  ('22', '105', 1.0),
#  ('551', '755', 4.0),
#  ('624', '473', 3.0),
#  ('900', '405', 3.0),
#  ('911', '154', 4.0),
#  ('887', '756', 5.0),
#  ('496', '380', 2.0),
#  ('500', '846', 3.0),
#  ('929', '182', 4.0),
#  ('655', '558', 4.0),
#  ('645', '186', 4.0),
#  ('729', '300', 4.0),
#  ('7', '51', 2.0),
#  ('519', '264', 2.0),
#  ('276', '22', 5.0),
#  ('848', '476', 3.0),
#  ('94', '39', 3.0),
#  ('564', '298', 3.0),
#  ('524', '161', 4.0),
#  ('749', '237', 3.0),
#  ('102', '288', 2.0),
#  ('784', '326', 5.0),
#  ('853', '678', 4.0),
#  ('334', '235', 3.0),
#  ('83', '371', 3.0),
#  ('796', '378', 4.0),
#  ('417', '411', 2.0),
#  ('377', '164', 4.0),
#  ('622', '277', 4.0),
#  ('889', '59', 4.0),
#  ('940', '855', 5.0),
#  ('574', '213', 4.0),
#  ('862', '200', 5.0),
#  ('846', '288', 4.0),
#  ('934', '254', 4.0),
#  ('568', '491', 2.0),
#  ('843', '501', 2.0),
#  ('894', '258', 4.0),
#  ('399', '407', 3.0),
#  ('448', '896', 5.0),
#  ('648', '118', 4.0),
#  ('406', '511', 5.0),
#  ('933', '665', 1.0),
#  ('586', '452', 3.0),
#  ('174', '582', 4.0),
#  ('497', '273', 4.0),
#  ('141', '274', 5.0),
#  ('96', '83', 3.0),
#  ('194', '518', 4.0),
#  ('472', '501', 3.0),
#  ('479', '144', 4.0),
#  ('698', '433', 4.0),
#  ('151', '748', 2.0),
#  ('907', '71', 5.0),
#  ('43', '1056', 3.0),
#  ('301', '31', 3.0),
#  ('11', '357', 5.0),
#  ('338', '435', 4.0),
#  ('85', '485', 5.0),
#  ('142', '895', 4.0),
#  ('442', '441', 3.0),
#  ('279', '294', 2.0),
#  ('277', '50', 3.0),
#  ('28', '229', 2.0),
#  ('736', '324', 3.0),
#  ('297', '202', 3.0),
#  ('85', '658', 3.0),
#  ('577', '204', 4.0),
#  ('405', '570', 1.0),
#  ('60', '265', 5.0),
#  ('258', '258', 2.0),
#  ('343', '302', 4.0),
#  ('26', '237', 3.0),
#  ('784', '327', 4.0),
#  ('103', '96', 4.0),
#  ('125', '49', 3.0),
#  ('715', '756', 2.0),
#  ('599', '288', 4.0),
#  ('671', '356', 3.0),
#  ('377', '258', 4.0),
#  ('804', '227', 4.0),
#  ('405', '140', 3.0),
#  ('144', '963', 4.0),
#  ('916', '381', 3.0),
#  ('13', '158', 1.0),
#  ('900', '493', 2.0),
#  ('422', '590', 2.0),
#  ('633', '96', 4.0),
#  ('880', '62', 3.0),
#  ('378', '924', 3.0),
#  ('279', '226', 4.0),
#  ('497', '951', 2.0),
#  ('696', '1126', 3.0),
#  ('416', '660', 5.0),
#  ('426', '607', 4.0),
#  ('543', '88', 4.0),
#  ('721', '22', 5.0),
#  ('661', '164', 4.0),
#  ('94', '47', 5.0),
#  ('642', '1037', 2.0),
#  ('536', '662', 5.0),
#  ('149', '305', 4.0),
#  ('676', '144', 4.0),
#  ('312', '601', 5.0),
#  ('650', '164', 4.0),
#  ('110', '569', 4.0),
#  ('615', '160', 3.0),
#  ('221', '117', 4.0),
#  ('924', '402', 3.0),
#  ('457', '304', 4.0),
#  ('880', '1496', 4.0),
#  ('90', '896', 3.0),
#  ('385', '529', 4.0),
#  ('895', '181', 5.0),
#  ('389', '396', 3.0),
#  ('328', '528', 5.0),
#  ('394', '288', 4.0),
#  ('433', '269', 5.0),
#  ('308', '494', 5.0),
#  ('160', '955', 4.0),
#  ('286', '1504', 4.0),
#  ('151', '69', 4.0),
#  ('469', '603', 5.0),
#  ('44', '228', 5.0),
#  ('193', '301', 4.0),
#  ('762', '749', 1.0),
#  ('539', '69', 5.0),
#  ('148', '227', 4.0),
#  ('846', '705', 3.0),
#  ('480', '517', 4.0),
#  ('90', '654', 5.0),
#  ('293', '1209', 2.0),
#  ('11', '120', 2.0),
#  ('892', '641', 5.0),
#  ('435', '234', 4.0),
#  ('673', '315', 5.0),
#  ('75', '1001', 1.0),
#  ('326', '550', 5.0),
#  ('94', '518', 5.0),
#  ('269', '68', 3.0),
#  ('374', '168', 1.0),
#  ('790', '959', 3.0),
#  ('537', '508', 4.0),
#  ('798', '210', 4.0),
#  ('727', '526', 4.0),
#  ('932', '470', 3.0),
#  ('221', '780', 3.0),
#  ('135', '379', 2.0),
#  ('43', '28', 4.0),
#  ('425', '201', 3.0),
#  ('291', '627', 4.0),
#  ('606', '313', 5.0),
#  ('113', '321', 3.0),
#  ('514', '180', 3.0),
#  ('774', '94', 2.0),
#  ('537', '213', 4.0),
#  ('229', '748', 3.0),
#  ('831', '273', 3.0),
#  ('686', '28', 4.0),
#  ('533', '748', 3.0),
#  ('398', '591', 3.0),
#  ('618', '191', 4.0),
#  ('123', '523', 3.0),
#  ('401', '405', 2.0),
#  ('637', '411', 1.0),
#  ('213', '200', 5.0),
#  ('70', '161', 3.0),
#  ('478', '708', 3.0),
#  ('334', '312', 2.0),
#  ('218', '186', 3.0),
#  ('577', '939', 5.0),
#  ('271', '31', 4.0),
#  ('496', '559', 5.0),
#  ('92', '743', 2.0),
#  ('586', '655', 4.0),
#  ('85', '258', 4.0),
#  ('746', '62', 3.0),
#  ('312', '487', 5.0),
#  ('311', '530', 3.0),
#  ('872', '118', 4.0),
#  ('428', '892', 4.0),
#  ('378', '401', 4.0),
#  ('339', '856', 5.0),
#  ('828', '190', 3.0),
#  ('311', '322', 4.0),
#  ('897', '168', 3.0),
#  ('323', '150', 4.0),
#  ('342', '584', 4.0),
#  ('276', '27', 3.0),
#  ('6', '151', 3.0),
#  ('305', '865', 3.0),
#  ('565', '923', 4.0),
#  ('532', '313', 5.0),
#  ('846', '1078', 2.0),
#  ('615', '213', 5.0),
#  ('128', '159', 4.0),
#  ('751', '405', 3.0),
#  ('303', '97', 5.0),
#  ('862', '22', 5.0),
#  ('189', '157', 4.0),
#  ('798', '83', 4.0),
#  ('901', '451', 4.0),
#  ('352', '12', 4.0),
#  ('206', '683', 1.0),
#  ('874', '306', 4.0),
#  ('503', '58', 4.0),
#  ('314', '1047', 4.0),
#  ('521', '81', 1.0),
#  ('449', '198', 4.0),
#  ('682', '552', 3.0),
#  ('416', '1132', 2.0),
#  ('244', '685', 2.0),
#  ('650', '472', 3.0),
#  ('69', '334', 3.0),
#  ('373', '275', 5.0),
#  ('343', '154', 5.0),
#  ('130', '215', 5.0),
#  ('615', '1021', 5.0),
#  ('776', '637', 3.0),
#  ('287', '301', 3.0),
#  ('378', '928', 2.0),
#  ('693', '130', 1.0),
#  ('292', '174', 5.0),
#  ('303', '384', 3.0),
#  ('354', '248', 4.0),
#  ('145', '356', 4.0),
#  ('529', '332', 4.0),
#  ('766', '674', 3.0),
#  ('788', '754', 4.0),
#  ('417', '1446', 3.0),
#  ('268', '328', 1.0),
#  ('60', '357', 4.0),
#  ('74', '285', 3.0),
#  ('429', '435', 4.0),
#  ('650', '504', 3.0),
#  ('313', '683', 3.0),
#  ('130', '79', 5.0),
#  ('465', '588', 4.0),
#  ('363', '473', 4.0),
#  ('486', '123', 3.0),
#  ('128', '168', 4.0),
#  ('311', '231', 4.0),
#  ('831', '328', 3.0),
#  ('886', '47', 4.0),
#  ('699', '324', 4.0),
#  ('593', '66', 5.0),
#  ('223', '155', 5.0),
#  ('380', '845', 4.0),
#  ('943', '2', 5.0),
#  ('271', '428', 4.0),
#  ('428', '302', 5.0),
#  ('456', '523', 4.0),
#  ('788', '211', 4.0),
#  ('7', '125', 4.0),
#  ('431', '302', 3.0),
#  ('548', '346', 4.0),
#  ('239', '1332', 3.0),
#  ('62', '33', 1.0),
#  ('867', '483', 5.0),
#  ('704', '89', 5.0),
#  ('451', '308', 1.0),
#  ('450', '478', 5.0),
#  ('747', '428', 3.0),
#  ('347', '105', 2.0),
#  ('106', '165', 5.0),
#  ('6', '197', 5.0),
#  ('216', '421', 5.0),
#  ('481', '484', 4.0),
#  ('835', '287', 4.0),
#  ('12', '480', 4.0),
#  ('119', '354', 5.0),
#  ('94', '208', 4.0),
#  ('389', '161', 2.0),
#  ('902', '298', 2.0),
#  ('742', '282', 3.0),
#  ('504', '1030', 3.0),
#  ('682', '346', 2.0),
#  ('255', '984', 1.0),
#  ('94', '720', 1.0),
#  ('270', '118', 3.0),
#  ('638', '511', 3.0),
#  ('405', '1488', 1.0),
#  ('347', '959', 5.0),
#  ('217', '222', 5.0),
#  ('880', '299', 4.0),
#  ('766', '514', 4.0),
#  ('782', '1665', 2.0),
#  ('305', '425', 4.0),
#  ('625', '222', 4.0),
#  ('405', '1503', 1.0),
#  ('633', '921', 3.0),
#  ('610', '51', 5.0),
#  ('572', '1171', 3.0),
#  ('244', '69', 4.0),
#  ('234', '404', 4.0),
#  ('452', '195', 4.0),
#  ('814', '200', 4.0),
#  ('747', '418', 5.0),
#  ('495', '227', 5.0),
#  ('315', '382', 4.0),
#  ('85', '275', 3.0),
#  ('291', '396', 4.0),
#  ('13', '301', 1.0),
#  ('301', '407', 2.0),
#  ('768', '245', 2.0),
#  ('689', '257', 5.0),
#  ('298', '511', 4.0),
#  ('605', '879', 3.0),
#  ('499', '12', 5.0),
#  ('313', '449', 3.0),
#  ('566', '631', 4.0),
#  ('862', '1117', 4.0),
#  ('157', '298', 4.0),
#  ('321', '480', 4.0),
#  ('442', '695', 5.0),
#  ('248', '210', 3.0),
#  ('896', '204', 4.0),
#  ('580', '358', 4.0),
#  ('586', '808', 3.0),
#  ('18', '191', 4.0),
#  ('62', '739', 2.0),
#  ('399', '5', 3.0),
#  ('303', '739', 5.0),
#  ('89', '301', 5.0),
#  ('721', '1065', 5.0),
#  ('234', '528', 4.0),
#  ('114', '135', 4.0),
#  ('757', '449', 3.0),
#  ('102', '363', 2.0),
#  ('537', '302', 4.0),
#  ('542', '1061', 2.0),
#  ('712', '739', 4.0),
#  ('193', '174', 4.0),
#  ('886', '150', 4.0),
#  ('889', '8', 3.0),
#  ('604', '7', 4.0),
#  ('504', '161', 4.0),
#  ('313', '391', 3.0),
#  ('62', '182', 5.0),
#  ('790', '181', 4.0),
#  ('716', '177', 2.0),
#  ('416', '366', 4.0),
#  ('278', '315', 4.0),
#  ('385', '318', 2.0),
#  ('159', '1152', 4.0),
#  ('886', '117', 2.0),
#  ('650', '631', 3.0),
#  ('177', '324', 4.0),
#  ('38', '356', 2.0),
#  ('860', '327', 3.0),
#  ('58', '45', 5.0),
#  ('295', '79', 4.0),
#  ('688', '359', 5.0),
#  ('121', '83', 4.0),
#  ('518', '7', 3.0),
#  ('416', '712', 4.0),
#  ('727', '1217', 3.0),
#  ('588', '159', 1.0),
#  ('846', '385', 5.0),
#  ('870', '1008', 3.0),
#  ('550', '121', 5.0),
#  ('85', '154', 4.0),
#  ('618', '815', 4.0),
#  ('683', '754', 3.0),
#  ('893', '147', 3.0),
#  ('646', '286', 3.0),
#  ('907', '318', 5.0),
#  ('747', '14', 3.0),
#  ('435', '943', 3.0),
#  ('506', '271', 4.0),
#  ('193', '871', 3.0),
#  ('75', '271', 5.0),
#  ('113', '424', 1.0),
#  ('861', '289', 5.0),
#  ('843', '526', 3.0),
#  ('643', '56', 5.0),
#  ('35', '1025', 3.0),
#  ('885', '756', 2.0),
#  ('130', '1228', 3.0),
#  ('295', '232', 3.0),
#  ('486', '1202', 4.0),
#  ('57', '477', 4.0),
#  ('722', '148', 3.0),
#  ('13', '815', 4.0),
#  ('155', '322', 2.0),
#  ('63', '286', 4.0),
#  ('561', '65', 3.0),
#  ('62', '117', 4.0),
#  ('815', '436', 3.0),
#  ('467', '1017', 2.0),
#  ('826', '779', 3.0),
#  ('426', '606', 5.0),
#  ('468', '428', 4.0),
#  ('622', '46', 4.0),
#  ('87', '100', 5.0),
#  ('698', '10', 4.0),
#  ('566', '467', 3.0),
#  ('524', '239', 2.0),
#  ('585', '1323', 3.0),
#  ('711', '200', 4.0),
#  ('506', '880', 1.0),
#  ('374', '248', 1.0),
#  ('207', '847', 3.0),
#  ('268', '824', 2.0),
#  ('286', '132', 5.0),
#  ('6', '59', 5.0),
#  ('513', '405', 3.0),
#  ('339', '56', 5.0),
#  ('540', '126', 3.0),
#  ('840', '511', 4.0),
#  ('480', '127', 3.0),
#  ('268', '181', 4.0),
#  ('265', '257', 4.0),
#  ('747', '64', 5.0),
#  ('698', '255', 3.0),
#  ('804', '152', 4.0),
#  ('453', '578', 3.0),
#  ('343', '561', 3.0),
#  ('601', '9', 4.0),
#  ('856', '322', 4.0),
#  ('499', '514', 5.0),
#  ('718', '1048', 2.0),
#  ('904', '289', 5.0),
#  ('16', '300', 5.0),
#  ('117', '358', 4.0),
#  ('919', '477', 4.0),
#  ('216', '27', 3.0),
#  ('655', '547', 4.0),
#  ('569', '288', 3.0),
#  ('293', '514', 4.0),
#  ('393', '627', 4.0),
#  ('704', '461', 3.0),
#  ('907', '198', 5.0),
#  ('17', '323', 1.0),
#  ('320', '202', 4.0),
#  ('749', '234', 4.0),
#  ('916', '42', 5.0),
#  ('933', '98', 5.0),
#  ('908', '195', 4.0),
#  ('109', '229', 5.0),
#  ('724', '938', 3.0),
#  ('676', '539', 4.0),
#  ('379', '1206', 2.0),
#  ('49', '90', 1.0),
#  ('200', '291', 3.0),
#  ('524', '181', 3.0),
#  ('453', '369', 2.0),
#  ('653', '210', 4.0),
#  ('399', '181', 3.0),
#  ('416', '8', 5.0),
#  ('766', '136', 3.0),
#  ('661', '727', 4.0),
#  ('90', '180', 4.0),
#  ('244', '238', 5.0),
#  ('880', '556', 3.0),
#  ('533', '65', 4.0),
#  ('299', '294', 2.0),
#  ('499', '915', 4.0),
#  ('927', '1089', 5.0),
#  ('178', '877', 2.0),
#  ('416', '21', 3.0),
#  ('667', '357', 5.0),
#  ('22', '554', 1.0),
#  ('562', '462', 5.0),
#  ('435', '225', 3.0),
#  ('891', '50', 4.0),
#  ('58', '475', 5.0),
#  ('13', '165', 3.0),
#  ('76', '327', 3.0),
#  ('805', '1105', 2.0),
#  ('194', '624', 2.0),
#  ('387', '135', 5.0),
#  ('828', '1062', 4.0),
#  ('347', '260', 1.0),
#  ('464', '249', 2.0),
#  ('223', '682', 4.0),
#  ('57', '1095', 2.0),
#  ('64', '475', 5.0),
#  ('134', '339', 2.0),
#  ('90', '316', 5.0),
#  ('790', '284', 4.0),
#  ('492', '318', 5.0),
#  ('864', '196', 4.0),
#  ('666', '510', 4.0),
#  ('484', '720', 4.0),
#  ('291', '943', 4.0),
#  ('5', '231', 2.0),
#  ('551', '950', 2.0),
#  ('794', '286', 3.0),
#  ('659', '649', 3.0),
#  ('819', '345', 4.0),
#  ('938', '823', 4.0),
#  ('272', '317', 4.0),
#  ('181', '544', 1.0),
#  ('416', '136', 5.0),
#  ('682', '685', 3.0),
#  ('772', '272', 5.0),
#  ('711', '88', 5.0),
#  ('562', '806', 1.0),
#  ('790', '68', 3.0),
#  ('735', '288', 4.0),
#  ('716', '1050', 4.0),
#  ('378', '1061', 2.0),
#  ('456', '324', 4.0),
#  ('903', '223', 5.0),
#  ('334', '153', 4.0),
#  ('738', '455', 4.0),
#  ('135', '33', 3.0),
#  ('436', '723', 3.0),
#  ('472', '125', 5.0),
#  ('620', '323', 5.0),
#  ('655', '165', 3.0),
#  ('15', '252', 2.0),
#  ('452', '636', 5.0),
#  ('405', '1391', 1.0),
#  ('122', '11', 1.0),
#  ('896', '258', 5.0),
#  ('13', '228', 4.0),
#  ('621', '405', 5.0),
#  ('401', '485', 4.0),
#  ('356', '892', 1.0),
#  ('864', '67', 4.0),
#  ('574', '328', 3.0),
#  ('830', '79', 4.0),
#  ('18', '739', 3.0),
#  ('870', '171', 4.0),
#  ('104', '273', 3.0),
#  ('494', '286', 4.0),
#  ('379', '69', 4.0),
#  ('293', '845', 2.0),
#  ('444', '1483', 2.0),
#  ('65', '69', 3.0),
#  ('561', '660', 3.0),
#  ('601', '504', 4.0),
#  ('222', '772', 2.0),
#  ('110', '364', 3.0),
#  ('853', '323', 3.0),
#  ('7', '602', 3.0),
#  ('60', '604', 4.0),
#  ('340', '480', 5.0),
#  ('5', '135', 4.0),
#  ('942', '172', 5.0),
#  ('936', '928', 3.0),
#  ('747', '208', 5.0),
#  ('642', '38', 4.0),
#  ('420', '690', 5.0),
#  ('856', '258', 4.0),
#  ('833', '1118', 3.0),
#  ('280', '389', 5.0),
#  ('308', '117', 3.0),
#  ('882', '117', 4.0),
#  ('606', '11', 5.0),
#  ('83', '43', 4.0),
#  ('252', '124', 5.0),
#  ('843', '99', 2.0),
#  ('198', '470', 3.0),
#  ('829', '213', 4.0),
#  ('228', '812', 5.0),
#  ('3', '347', 5.0),
#  ('324', '282', 5.0),
#  ('682', '625', 3.0),
#  ('579', '328', 3.0),
#  ('447', '70', 3.0),
#  ('11', '728', 3.0),
#  ('707', '506', 2.0),
#  ('484', '241', 3.0),
#  ('451', '259', 4.0),
#  ('694', '641', 4.0),
#  ('31', '340', 3.0),
#  ('197', '679', 1.0),
#  ('152', '153', 4.0),
#  ('790', '940', 3.0),
#  ('276', '447', 4.0),
#  ('267', '576', 3.0),
#  ('194', '235', 2.0),
#  ('387', '203', 4.0),
#  ('109', '158', 1.0),
#  ('642', '153', 3.0),
#  ('770', '328', 3.0),
#  ('233', '64', 5.0),
#  ('137', '405', 5.0),
#  ('405', '1021', 1.0),
#  ('659', '657', 5.0),
#  ('630', '325', 3.0),
#  ('87', '47', 3.0),
#  ('297', '83', 4.0),
#  ('699', '243', 2.0),
#  ('497', '657', 3.0),
#  ('190', '742', 3.0),
#  ('940', '521', 4.0),
#  ('435', '185', 4.0),
#  ('771', '709', 5.0),
#  ('334', '1170', 4.0),
#  ('886', '132', 3.0),
#  ('804', '520', 4.0),
#  ('435', '240', 3.0),
#  ('49', '420', 4.0),
#  ('286', '546', 1.0),
#  ('399', '545', 2.0),
#  ('269', '1411', 3.0),
#  ('43', '77', 3.0),
#  ('316', '19', 5.0),
#  ('217', '56', 5.0),
#  ('892', '483', 5.0),
#  ('223', '1150', 2.0),
#  ('204', '191', 4.0),
#  ('236', '88', 2.0),
#  ('496', '528', 4.0),
#  ('778', '249', 3.0),
#  ('393', '84', 3.0),
#  ('1', '255', 2.0),
#  ('656', '346', 3.0),
#  ('465', '428', 3.0),
#  ('660', '252', 2.0),
#  ('26', '546', 2.0),
#  ('548', '887', 4.0),
#  ('551', '183', 4.0),
#  ('222', '12', 5.0),
#  ('178', '333', 3.0),
#  ('270', '185', 5.0),
#  ('840', '1674', 4.0),
#  ('37', '127', 4.0),
#  ('883', '707', 3.0),
#  ('716', '570', 3.0),
#  ('21', '767', 1.0),
#  ('751', '214', 4.0),
#  ('416', '396', 2.0),
#  ('605', '523', 5.0),
#  ('263', '432', 2.0),
#  ('562', '98', 4.0),
#  ('358', '382', 2.0),
#  ('314', '833', 4.0),
#  ('559', '205', 5.0),
#  ('409', '1093', 2.0),
#  ('10', '699', 4.0),
#  ('301', '8', 4.0),
#  ('59', '99', 4.0),
#  ('406', '478', 4.0),
#  ('246', '231', 1.0),
#  ('234', '70', 3.0),
#  ('255', '328', 2.0),
#  ('650', '674', 4.0),
#  ('763', '972', 3.0),
#  ('551', '281', 5.0),
#  ('328', '282', 3.0),
#  ('660', '197', 3.0),
#  ('846', '194', 4.0),
#  ('923', '544', 4.0),
#  ('435', '930', 3.0),
#  ('119', '710', 4.0),
#  ('608', '886', 1.0),
#  ('314', '106', 2.0),
#  ('762', '875', 5.0),
#  ('796', '218', 3.0),
#  ('815', '265', 5.0),
#  ('157', '250', 1.0),
#  ('450', '588', 4.0),
#  ('181', '1033', 1.0),
#  ('119', '1263', 3.0),
#  ('863', '294', 4.0),
#  ('151', '582', 5.0),
#  ('373', '238', 4.0),
#  ('398', '796', 3.0),
#  ('865', '547', 5.0),
#  ('727', '549', 3.0),
#  ('707', '186', 3.0),
#  ('724', '338', 3.0),
#  ('663', '710', 3.0),
#  ('908', '482', 3.0),
#  ('666', '168', 4.0),
#  ('406', '12', 4.0),
#  ('344', '357', 5.0),
#  ('59', '931', 2.0),
#  ('251', '22', 5.0),
#  ('416', '1147', 4.0),
#  ('451', '886', 4.0),
#  ('425', '452', 2.0),
#  ('406', '638', 4.0),
#  ('82', '1128', 1.0),
#  ('833', '430', 4.0),
#  ('777', '135', 3.0),
#  ('749', '746', 5.0),
#  ('459', '1047', 3.0),
#  ('291', '325', 4.0),
#  ('85', '215', 4.0),
#  ('936', '3', 4.0),
#  ('815', '451', 3.0),
#  ('694', '15', 4.0),
#  ('417', '234', 4.0),
#  ('244', '433', 5.0),
#  ('49', '4', 2.0),
#  ('85', '234', 4.0),
#  ('378', '1478', 3.0),
#  ('119', '1016', 5.0),
#  ('561', '1153', 3.0),
#  ('524', '64', 2.0),
#  ('498', '594', 2.0),
#  ('214', '151', 5.0),
#  ('239', '124', 5.0),
#  ('393', '1435', 3.0),
#  ('856', '310', 3.0),
#  ('510', '325', 1.0),
#  ('828', '213', 2.0),
#  ('387', '209', 5.0),
#  ('697', '127', 5.0),
#  ('721', '357', 5.0),
#  ('682', '999', 2.0),
#  ('528', '1254', 3.0),
#  ('242', '1357', 5.0),
#  ('481', '505', 5.0),
#  ('901', '1643', 5.0),
#  ('456', '498', 4.0),
#  ('92', '93', 4.0),
#  ('776', '187', 4.0),
#  ('634', '676', 4.0),
#  ('311', '423', 5.0),
#  ('790', '568', 3.0),
#  ('894', '472', 3.0),
#  ('723', '50', 4.0),
#  ('85', '173', 3.0),
#  ('650', '1149', 4.0),
#  ('198', '431', 3.0),
#  ('937', '864', 3.0),
#  ('176', '876', 3.0),
#  ('447', '591', 4.0),
#  ('406', '372', 4.0),
#  ('886', '715', 1.0),
#  ('796', '271', 5.0),
#  ('708', '926', 3.0),
#  ('83', '38', 5.0),
#  ('297', '20', 4.0),
#  ('181', '324', 1.0),
#  ('610', '480', 5.0),
#  ('1', '53', 3.0),
#  ('274', '243', 2.0),
#  ('38', '452', 5.0),
#  ('541', '404', 4.0),
#  ('312', '631', 5.0),
#  ('854', '455', 2.0),
#  ('597', '283', 5.0),
#  ('932', '841', 2.0),
#  ('327', '732', 1.0),
#  ('553', '478', 4.0),
#  ('303', '762', 4.0),
#  ('114', '191', 3.0),
#  ('372', '326', 4.0),
#  ('896', '168', 4.0),
#  ('148', '168', 5.0),
#  ('7', '89', 5.0),
#  ('81', '591', 5.0),
#  ('87', '1047', 3.0),
#  ('489', '321', 3.0),
#  ('709', '11', 5.0),
#  ('559', '196', 5.0),
#  ('137', '249', 4.0),
#  ('94', '32', 5.0),
#  ('13', '506', 5.0),
#  ('881', '286', 2.0),
#  ('18', '137', 5.0),
#  ('916', '183', 4.0),
#  ('804', '401', 2.0),
#  ('52', '473', 4.0),
#  ('840', '509', 3.0),
#  ('865', '24', 4.0),
#  ('293', '68', 3.0),
#  ('271', '276', 3.0),
#  ('301', '871', 4.0),
#  ('95', '142', 4.0),
#  ('756', '1119', 4.0),
#  ('389', '531', 4.0),
#  ('798', '705', 4.0),
#  ('796', '243', 3.0),
#  ('292', '405', 3.0),
#  ('615', '736', 5.0),
#  ('327', '169', 2.0),
#  ('96', '519', 4.0),
#  ('184', '127', 5.0),
#  ('399', '658', 3.0),
#  ('758', '237', 4.0),
#  ('913', '527', 5.0),
#  ('835', '1153', 4.0),
#  ('682', '65', 3.0),
#  ('500', '1008', 4.0),
#  ('854', '514', 4.0),
#  ('311', '499', 4.0),
#  ('751', '173', 4.0),
#  ('497', '169', 4.0),
#  ('846', '796', 1.0),
#  ('664', '215', 4.0),
#  ('844', '216', 5.0),
#  ('361', '275', 4.0),
#  ('500', '257', 3.0),
#  ('234', '496', 4.0),
#  ('795', '257', 3.0),
#  ('500', '143', 3.0),
#  ('417', '616', 2.0),
#  ('898', '309', 5.0),
#  ('593', '193', 4.0),
#  ('561', '173', 4.0),
#  ('200', '89', 5.0),
#  ('407', '96', 3.0),
#  ('349', '285', 5.0),
#  ('412', '4', 3.0),
#  ('644', '328', 4.0),
#  ('514', '48', 4.0),
#  ('589', '328', 5.0),
#  ('109', '1', 4.0),
#  ('195', '109', 3.0),
#  ('361', '212', 5.0),
#  ('846', '200', 4.0),
#  ('894', '1251', 4.0),
#  ('727', '739', 4.0),
#  ('908', '654', 3.0),
#  ('533', '357', 3.0),
#  ('279', '202', 4.0),
#  ('648', '434', 5.0),
#  ('198', '559', 3.0),
#  ('7', '27', 4.0),
#  ('405', '64', 5.0),
#  ('862', '127', 5.0),
#  ('327', '153', 4.0),
#  ('92', '934', 2.0),
#  ('405', '802', 1.0),
#  ('102', '164', 3.0),
#  ('634', '325', 1.0),
#  ('142', '463', 3.0),
#  ('200', '802', 4.0),
#  ('551', '4', 2.0),
#  ('385', '922', 4.0),
#  ('599', '873', 5.0),
#  ('245', '222', 4.0),
#  ('747', '644', 5.0),
#  ('200', '151', 3.0),
#  ('577', '77', 3.0),
#  ('15', '685', 4.0),
#  ('435', '385', 5.0),
#  ('655', '927', 3.0),
#  ('150', '13', 4.0),
#  ('308', '139', 3.0),
#  ('429', '1545', 2.0),
#  ('436', '65', 4.0),
#  ('13', '237', 5.0),
#  ('234', '1205', 1.0),
#  ('579', '209', 4.0),
#  ('280', '655', 3.0),
#  ('267', '250', 5.0),
#  ('338', '606', 3.0),
#  ('405', '849', 1.0),
#  ('593', '183', 4.0),
#  ('912', '174', 3.0),
#  ('775', '305', 4.0),
#  ('847', '1050', 3.0),
#  ('870', '154', 4.0),
#  ('485', '245', 3.0),
#  ('495', '132', 4.0),
#  ('295', '404', 4.0),
#  ('145', '826', 2.0),
#  ('209', '898', 3.0),
#  ('343', '197', 4.0),
#  ('561', '515', 3.0),
#  ('633', '526', 4.0),
#  ('481', '663', 4.0),
#  ('339', '515', 5.0),
#  ('680', '274', 3.0),
#  ('827', '272', 4.0),
#  ('880', '381', 4.0),
#  ('361', '173', 5.0),
#  ('834', '255', 3.0),
#  ('707', '137', 5.0),
#  ('119', '1244', 3.0),
#  ('798', '1411', 1.0),
#  ('805', '382', 4.0),
#  ('757', '895', 4.0),
#  ('368', '127', 4.0),
#  ('94', '12', 4.0),
#  ('128', '180', 5.0),
#  ('577', '808', 3.0),
#  ('416', '724', 4.0),
#  ('244', '949', 4.0),
#  ('313', '504', 5.0),
#  ('498', '806', 3.0),
#  ('201', '196', 4.0),
#  ('167', '364', 3.0),
#  ('271', '476', 1.0),
#  ('602', '538', 4.0),
#  ('365', '1011', 3.0),
#  ('432', '546', 3.0),
#  ('271', '521', 5.0),
#  ('48', '195', 5.0),
#  ('230', '237', 5.0),
#  ('682', '820', 3.0),
#  ('618', '118', 3.0),
#  ('642', '78', 3.0),
#  ('379', '234', 5.0),
#  ('417', '640', 5.0),
#  ('741', '82', 3.0),
#  ('814', '5', 3.0),
#  ('533', '127', 5.0),
#  ('553', '186', 3.0),
#  ('498', '337', 4.0),
#  ('467', '1142', 5.0),
#  ('821', '213', 5.0),
#  ('452', '187', 3.0),
#  ('339', '74', 4.0),
#  ('279', '978', 1.0),
#  ('774', '550', 2.0),
#  ('584', '181', 4.0),
#  ('194', '1112', 3.0),
#  ('497', '395', 4.0),
#  ('391', '191', 3.0),
#  ('254', '416', 4.0),
#  ('790', '235', 1.0),
#  ('234', '50', 4.0),
#  ('782', '894', 2.0),
#  ('684', '158', 3.0),
#  ('664', '169', 5.0),
#  ('21', '981', 2.0),
#  ('535', '955', 3.0),
#  ('109', '239', 4.0),
#  ('387', '226', 3.0),
#  ('919', '333', 4.0),
#  ('619', '118', 5.0),
#  ('655', '1466', 3.0),
#  ...]

# %%
test_df = pd.DataFrame(testset, columns=['userId', 'itemId', 'rating'])

# %%
test_df
# Out:
#       userId itemId  rating
# 0        532    215     5.0
# 1        222    549     4.0
# 2        404    323     3.0
# 3        869    122     3.0
# 4        631    288     3.0
# ...      ...    ...     ...
# 19995    316    730     4.0
# 19996    472    100     5.0
# 19997    847     89     2.0
# 19998    566    523     4.0
# 19999    734    821     2.0
#
# [20000 rows x 3 columns]

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   userId  20000 non-null  object
#  1   itemId  20000 non-null  object
#  2   rating  20000 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 468.9+ KB

# %%
test_df.describe()
# Out:
#              rating
# count  20000.000000
# mean       3.531800
# std        1.126522
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        4.000000
# max        5.000000

# %%
len(test_df['userId'].unique())
# Out:
# 940

# %%
len(test_df['itemId'].unique())
# Out:
# 1407

# %%
skf = StratifiedKFold(n_splits=10)

# %%
skf.get_n_splits(data)
# Out:
# 10

# %% [markdown]
# # CrossValidatuion

# %% [markdown]
# ##### SVD

# %%
algo = SVD()

cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9330  0.9423  0.9325  0.9365  0.9412  0.9371  0.0041
# MAE (testset)     0.7349  0.7399  0.7378  0.7382  0.7447  0.7391  0.0032
# Fit time          3.19    2.75    2.62    2.74    2.71    2.80    0.20
# Test time         0.43    0.52    0.39    0.33    0.49    0.43    0.07
# {'test_rmse': array([0.93299526, 0.94228004, 0.93248244, 0.93649278, 0.94121464]),
#  'test_mae': array([0.7349332 , 0.73985239, 0.73781019, 0.73824257, 0.74467361]),
#  'fit_time': (3.1932382583618164,
#   2.7489240169525146,
#   2.6160340309143066,
#   2.7431483268737793,
#   2.705244302749634),
#  'test_time': (0.4259927272796631,
#   0.5199122428894043,
#   0.38695788383483887,
#   0.3340020179748535,
#   0.489959716796875)}

# %% [markdown]
# ##### SVD++

# %%
algo = SVDpp()

cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVDpp on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9235  0.9185  0.9220  0.9104  0.9212  0.9191  0.0047
# MAE (testset)     0.7237  0.7221  0.7251  0.7153  0.7184  0.7209  0.0036
# Fit time          66.37   57.86   62.90   62.68   57.92   61.54   3.26
# Test time         13.30   11.33   12.71   11.22   15.99   12.91   1.73
# {'test_rmse': array([0.92347784, 0.91850277, 0.92198187, 0.91039763, 0.92124925]),
#  'test_mae': array([0.72367634, 0.72207942, 0.7251376 , 0.71534139, 0.71842391]),
#  'fit_time': (66.3666479587555,
#   57.85632014274597,
#   62.896240234375,
#   62.679577589035034,
#   57.92180681228638),
#  'test_time': (13.304041862487793,
#   11.325393199920654,
#   12.709648132324219,
#   11.215431928634644,
#   15.985170841217041)}

# %% [markdown]
# ##### MNF

# %%
algo = NMF()

cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm NMF on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9601  0.9587  0.9605  0.9605  0.9664  0.9613  0.0026
# MAE (testset)     0.7531  0.7553  0.7546  0.7559  0.7588  0.7555  0.0019
# Fit time          5.14    4.97    4.49    4.31    7.12    5.21    1.00
# Test time         0.50    0.34    0.35    0.42    0.57    0.44    0.09
# {'test_rmse': array([0.96012636, 0.95872598, 0.96051299, 0.96051929, 0.9663786 ]),
#  'test_mae': array([0.7530903 , 0.75532507, 0.75462731, 0.75586459, 0.75878516]),
#  'fit_time': (5.139596462249756,
#   4.967195749282837,
#   4.494403600692749,
#   4.307634592056274,
#   7.119093894958496),
#  'test_time': (0.5018303394317627,
#   0.3395254611968994,
#   0.35100221633911133,
#   0.41699957847595215,
#   0.5720994472503662)}

# %% [markdown]
# # Sampling

# %%
all_ratings = data.raw_ratings
print(f"Total number of ratings in the dataset: {len(all_ratings)}")
# Out:
# Total number of ratings in the dataset: 100000

# %%
slice_ratings = raw_ratings[:1000]

ratings_df = pd.DataFrame(slice_ratings, columns=['user', 'item', 'rating', 'timestamp']).drop(columns=['timestamp'])


# reader = Reader(rating_scale=(1, 5))
sample = DatasetAutoFolds(df=ratings_df, reader=reader)

# Печатаем информацию о новом наборе данных для проверки
print(f"Total number of ratings in the new dataset: {len(sample.raw_ratings)}")
# Out:
# Total number of ratings in the new dataset: 1000

# %% [markdown]
# # GridSearch

# %% [markdown]
# ##### SVD

# %%
param_grid = {
    'n_factors': [10,20],
    'n_epochs': [10, 20],
    'lr_all': [0.005, 0.01],
    'reg_all': [0.05, 0.1]
}

# %%
gs_svd = GridSearchCV(SVD, param_grid, measures=['rmse'], cv=5, n_jobs=-1)
for i in trange(100):
  gs_svd.fit(sample)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
best_params_svd = gs_svd.best_params['rmse']

# %% [markdown]
# ##### SVD++

# %%
gs_svdpp = GridSearchCV(SVDpp, param_grid, measures=['rmse'], cv=5, n_jobs=-1)
for i in trange(100):
  gs_svd.fit(sample)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
best_params_svdpp = gs_svdpp.best_params['rmse']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 best_params_svdpp = gs_svdpp.best_params['rmse']
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params'

# %% [markdown]
# ##### NMF

# %%
param_grid_nmf = {
    'n_factors': [10, 20],
    'n_epochs': [10, 20],
    'lr_bu': [ 0.005, 0.01],
    'lr_bi': [ 0.005, 0.01],
    'reg_bu': [0.05, 0.1],
    'reg_bi': [0.05, 0.1]
}

# %%
gs_nmf = GridSearchCV(NMF, param_grid_nmf, measures=['rmse'], cv=5, n_jobs=-1)
for i in trange(100):
  gs_nmf.fit(sample)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
best_params_nmf = gs_nmf.best_params['rmse']

# %%
print(f"Best parameters for SVD: {best_params_svd}")
# print(f"Best parameters for SVD++: {best_params_svdpp}")
print(f"Best parameters for NMF: {best_params_nmf}")
# Out:
# Best parameters for SVD: {'n_factors': 10, 'n_epochs': 10, 'lr_all': 0.01, 'reg_all': 0.05}
# Best parameters for NMF: {'n_factors': 20, 'n_epochs': 20, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.1, 'reg_bi': 0.1}

# %% [markdown]
# # Result

# %%
algo_svd = SVD(**best_params_svd)
algo_svdpp = SVDpp(**best_params_svd)
algo_nmf = NMF(**best_params_nmf)

# %%
cv_results_svd = cross_validate(algo_svd, data, measures=['rmse'], cv=5, verbose=True)
# Out:
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9454  0.9432  0.9436  0.9326  0.9357  0.9401  0.0050
# Fit time          1.50    1.22    1.25    4.63    1.28    1.98    1.33
# Test time         0.46    0.78    0.95    0.75    0.73    0.73    0.16

# %%
cv_results_svdpp = cross_validate(algo_svdpp, data, measures=['rmse'], cv=5, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 cv_results_svdpp = cross_validate(algo_svdpp, data, measures=['rmse'], cv=5, verbose=True)
#
# File c:\Users\nasta\anaconda3\Lib\site-packages\surprise\model_selection\validation.py:108, in cross_validate(algo, data, measures, cv, return_train_measures, n_jobs, pre_dispatch, verbose)
#     102 cv = get_cv(cv)
#     104 delayed_list = (
#     105     delayed(fit_and_score)(algo, trainset, testset, measures, return_train_measures)
#     106     for (trainset, testset) in cv.split(data)
#     107 )
# --> 108 out = Parallel(n_jobs=n_jobs, pre_dispatch=pre_dispatch)(delayed_list)
#     110 (test_measures_dicts, train_measures_dicts, fit_times, test_times) = zip(*out)
#     112 test_measures = dict()
#
# File c:\Users\nasta\anaconda3\Lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File c:\Users\nasta\anaconda3\Lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File c:\Users\nasta\anaconda3\Lib\site-packages\surprise\model_selection\validation.py:173, in fit_and_score(algo, trainset, testset, measures, return_train_measures)
#     142 """Helper method that trains an algorithm and compute accuracy measures on
#     143 a testset. Also report train and test times.
#     144
#    (...)
#     169         - The testing time in seconds.
#     170 """
#     172 start_fit = time.time()
# --> 173 algo.fit(trainset)
#     174 fit_time = time.time() - start_fit
#     175 start_test = time.time()
#
# File c:\Users\nasta\anaconda3\Lib\site-packages\surprise\prediction_algorithms\matrix_factorization.pyx:400, in surprise.prediction_algorithms.matrix_factorization.SVDpp.fit()
#
# File c:\Users\nasta\anaconda3\Lib\site-packages\surprise\prediction_algorithms\matrix_factorization.pyx:464, in surprise.prediction_algorithms.matrix_factorization.SVDpp.sgd()
#
# File c:\Users\nasta\anaconda3\Lib\site-packages\surprise\trainset.py:194, in Trainset.all_ratings(self)
#     192 for u, u_ratings in self.ur.items():
#     193     for i, r in u_ratings:
# --> 194         yield u, i, r
#
# KeyboardInterrupt:

# %%
cv_results_nmf = cross_validate(algo_nmf, data, measures=['rmse'], cv=5, verbose=True)
# Out:
# Evaluating RMSE of algorithm NMF on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1205  1.1060  1.1066  1.1036  1.1060  1.1085  0.0061
# Fit time          2.99    2.90    2.44    3.43    4.36    3.23    0.65
# Test time         0.33    0.37    0.93    0.48    1.01    0.62    0.29

# %%
print(f"Mean RMSE for SVD: {cv_results_svd['test_rmse'].mean()}")
# print(f"Mean RMSE for SVD++: {cv_results_svdpp['test_rmse'].mean()}")
print(f"Mean RMSE for NMF: {cv_results_nmf['test_rmse'].mean()}")
# Out:
# Mean RMSE for SVD: 0.9400970174401412
# Mean RMSE for NMF: 1.1085275340546865

# %% [markdown]
# # Fit

# %%
for i in trange(100):
    algo_svd.fit(trainset)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
for i in trange(100):
    algo_svdpp.fit(trainset)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
for i in trange(100):
    algo_nmf.fit(trainset)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
data

# %% [markdown]
# # Test

# %%
userId = 794

# %%
items_to_recommend = [238]

# %%
for itemId in items_to_recommend:
    prediction = algo_svd.predict(userId, itemId)
    print(f"Рекомендований рейтинг для користувача {userId} та об'єкта {itemId}: {prediction.est}")
# Out:
# Рекомендований рейтинг для користувача 794 та об'єкта 238: 3.52986

# %%
for itemId in items_to_recommend:
    prediction = algo_nmf.predict(userId, itemId)
    print(f"Рекомендований рейтинг для користувача {userId} та об'єкта {itemId}: {prediction.est}")
# Out:
# Рекомендований рейтинг для користувача 794 та об'єкта 238: 3.52986

# %%
for itemId in items_to_recommend:
    prediction = algo_svdpp.predict(userId, itemId)
    print(f"Рекомендований рейтинг для користувача {userId} та об'єкта {itemId}: {prediction.est}")
# Out:
# Рекомендований рейтинг для користувача 794 та об'єкта 238: 3.52986
